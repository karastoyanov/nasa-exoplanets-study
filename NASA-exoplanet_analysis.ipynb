# %%
# Download source csv - https://exoplanetarchive.ipac.caltech.edu/cgi-bin/TblView/nph-tblView?app=ExoTbls&config=PS

# %% [markdown]
# ### NASA's search for another earth.
#
# #### Current project aims to give insights on the search of another life in our Universe and the method used by NASA in discovering another worlds out there.

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read CSV file from local source
spreadsheet = pd.read_csv('src/nasa_exoplanets.csv', delimiter = ',', low_memory = False)
spreadsheet.head()
# Out:
#     pl_name hostname  default_flag  sy_snum  sy_pnum  discoverymethod  \
# 0  11 Com b   11 Com             1        2        1  Radial Velocity
# 1  11 Com b   11 Com             0        2        1  Radial Velocity
# 2  11 UMi b   11 UMi             0        1        1  Radial Velocity
# 3  11 UMi b   11 UMi             0        1        1  Radial Velocity
# 4  11 UMi b   11 UMi             1        1        1  Radial Velocity
#
#    disc_year                           disc_facility              soltype  \
# 0       2007                        Xinglong Station  Published Confirmed
# 1       2007                        Xinglong Station  Published Confirmed
# 2       2009  Thueringer Landessternwarte Tautenburg  Published Confirmed
# 3       2009  Thueringer Landessternwarte Tautenburg  Published Confirmed
# 4       2009  Thueringer Landessternwarte Tautenburg  Published Confirmed
#
#    pl_controv_flag  ... sy_gaiamagerr2   rowupdate pl_pubdate releasedate  \
# ...

# %%
df = pd.DataFrame(spreadsheet)
years = []
for year in df.disc_year:
    if year not in years:
        years.append(int(year))
    years.sort()
print(f'Years of discoveries: {",".join([str(x) for x in years])}')

planets_by_year = {"Year": "Number"}
for year in range(len(years)):
    current_year = str(years[year])
    number_planets_found = df.query(f"disc_year == '{current_year}'")
    planets_by_year[current_year] = len(number_planets_found)
    print(f'Total number of exoplanets found in {current_year}: {len(number_planets_found)}')
# Out:
# Years of discoveries: 1992,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023
# Total number of exoplanets found in 1992: 6
# Total number of exoplanets found in 1994: 2
# Total number of exoplanets found in 1995: 5
# Total number of exoplanets found in 1996: 41
# Total number of exoplanets found in 1997: 3
# Total number of exoplanets found in 1998: 38
# Total number of exoplanets found in 1999: 76
# Total number of exoplanets found in 2000: 77
# Total number of exoplanets found in 2001: 56
# Total number of exoplanets found in 2002: 139
# Total number of exoplanets found in 2003: 78
# Total number of exoplanets found in 2004: 165
# Total number of exoplanets found in 2005: 152
# Total number of exoplanets found in 2006: 139
# Total number of exoplanets found in 2007: 294
# Total number of exoplanets found in 2008: 310
# Total number of exoplanets found in 2009: 385
# ...

# %%
courses = list(planets_by_year.keys())
values = list(planets_by_year.values())
fig = plt.figure(figsize = (80, 15))
courses = courses[1:-1]
values = values[1:-1]

plt.pie(values, labels = ([str(x) for x in courses]))
plt.show()
